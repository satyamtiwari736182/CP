# %%
print('Hello world!😀')
# Out:
# Hello world!😀

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# arr=np.zeros(shape=(4,5))
# arr1=np.arange(1,10,1)
# print(arr)
# print(arr1)
# print('----------------')
# arr=arr.reshape((2,10))
# arr1=arr1.reshape((3,3))
# print(arr)
# print(arr1)
# print('----------------')
# arr=np.eye(4)
# print(arr)
# print('----------------')
# arr=np.random.randint(1,20,(3,4))
# print(arr)
# print('----------------')
# print(arr[1:,1:3])

# print(f'mean: {np.mean(arr)}')
# print(f'median: {np.median(arr)}')
# print(f'std: {np.std(arr)}')
# print(f'var: {np.var(arr)}')
# print('----------------')

# arr1=np.random.rand(3,4)*100
# print(arr1)
# print('----------------')
# print(arr * arr1)
# arr=arr.reshape((4,3))
# print('----------------')
# print(np.dot(arr,arr1))
print('----------------')
arr=np.random.randint(1,20,(2,2))*10

print(f'|arr|: {np.linalg.det(arr)}')
print(f'eign(arr):\n{np.linalg.eig(arr)}')
print(f'inv(arr):\n{np.linalg.inv(arr)}')
# Out:
# ----------------
# |arr|: 7300.000000000002
# eign(arr):
# EigResult(eigenvalues=array([227.97958971,  32.02041029]), eigenvectors=array([[ 0.90743663, -0.86940733],
#        [ 0.42018896,  0.49409604]]))
# inv(arr):
# [[ 0.01643836 -0.0260274 ]
#  [-0.00684932  0.01917808]]

# %%
# data=pd.read_csv('data.csv')
data=[['satyam','tiwari',45],
['rahul','kashyap',34],
['deepak','sha',54]]
data=np.array(data)
print(data)
df=pd.DataFrame(data=data,columns=['firstName','lastName','age'])
df
# Out:
# [['satyam' 'tiwari' '45']
#  ['rahul' 'kashyap' '34']
#  ['deepak' 'sha' '54']]
#   firstName lastName age
# 0    satyam   tiwari  45
# 1     rahul  kashyap  34
# 2    deepak      sha  54

# %%
print(df[['firstName','age']])
print(df.loc[1,'firstName'])
print(df.iloc[1,1])

df.dtypes
df['age']=df['age'].astype(int)
df.dtypes
df[df['age'] > 40]  # Rows where Age > 30
# Out:
#   firstName  age
# 0    satyam   45
# 1     rahul   34
# 2    deepak   54
# rahul
# kashyap
#   firstName lastName  age
# 0    satyam   tiwari   45
# 2    deepak      sha   54

# %%
fig,axes=plt.subplots(nrows=2,ncols=4,figsize=(40,15))
# Out:
# <Axes: >

# %%
n=5
dp = [[0] for _ in range(n)]
dp
# Out:
# [[0], [0], [0], [0], [0]]
